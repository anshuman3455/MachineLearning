# %%
import numpy as np 
import pandas as pd

# %%
# df = pd.read_csv("C:\\Users\\saurabh\\Desktop\\pyth\\titanic.csv")
df = pd.read_csv("C:\\Users\\user\\Downloads\\titanic.csv")

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# 1. univariate Analysis 

# 1. countplot

# %%
df['Survived'].value_counts()
# Out:
# 0    266
# 1    152
# Name: Survived, dtype: int64

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(x = df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: >

# %%
df['Pclass'].value_counts()
# Out:
# 3    218
# 1    107
# 2     93
# Name: Pclass, dtype: int64

# %%
sns.countplot(df['Pclass'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind = 'pie' , autopct = '%.2f')
# Out:
# <Axes: ylabel='Survived'>

# %%
plt.hist(df['Age'])
plt.show()

# %%
sns.distplot(df['Age'])   #kde = kernal density extraction
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8232\4184689886.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])   #kde = kernal density extraction
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df = pd.read_csv("C:\\Users\\user\\Downloads\\tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# 2. Bivariate Analysis

# %%
sns.scatterplot(x=df['total_bill'] , y=df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x = df['total_bill'] , y= df['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
# Multivariate Analysis

# %%
sns.scatterplot(x = df['total_bill'] , y = df['tip'] , hue =  df['sex'])
plt.show()

# %%
sns.scatterplot(x = df['total_bill'] , y = df['tip'] , style =  df['sex'])
plt.show()

# %%
sns.barplot(x = df['total_bill'] , y = df['tip'] , hue = df['time'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
df = pd.read_csv("C:\\Users\\user\\Downloads\\titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
sns.barplot(x = df['Pclass'] , y = df['Fare'] , hue = df['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.boxplot(x=df['Sex'] ,y= df['Age'] , hue = df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.pairplot(df)

# %%
((df.groupby('Pclass').mean()['Survived'])*100).plot(kind = 'bar')
((df.groupby('Pclass').mean()['Survived'])*100)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8232\3243517202.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ((df.groupby('Pclass').mean()['Survived'])*100).plot(kind = 'bar')
# C:\Users\user\AppData\Local\Temp\ipykernel_8232\3243517202.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   ((df.groupby('Pclass').mean()['Survived'])*100)
# Pclass
# 1    46.728972
# 2    32.258065
# 3    33.027523
# Name: Survived, dtype: float64
